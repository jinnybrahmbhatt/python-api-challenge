# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import geopy
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
#import citipy
from citipy import citipy
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 576

# %% [markdown]
# ---

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf'

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url =  "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Start Data Retrieval     ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for x, city in enumerate(cities):
    
    if (x % 50 ==0 and x >= 50):
        set_count =+ 1
        record_count = 0
    
    city_url = url + "&q=" + city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    print(city_url)
    
    record_count = 1
    
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass
        
print("-------------------------------------")
print("Data Retrieval Complete")
print("-------------------------------------")
# Out:
# Start Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mataura
# Processing Record 1 of Set 1 | batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=batagay
# Processing Record 1 of Set 1 | dabrowa tarnowska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=dabrowa tarnowska
# Processing Record 1 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cape town
# Processing Record 1 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=jamestown
# Processing Record 1 of Set 1 | eregli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=eregli
# Processing Record 1 of Set 1 | agropoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=agropoli
# Processing Record 1 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=castro
# Processing Record 1 of Set 1 | buqayq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=buqayq
# City not found. Skipping...
# Processing Record 1 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bethel
# Processing Record 1 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=puerto ayora
# Processing Record 1 of Set 1 | khromtau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=khromtau
# Processing Record 1 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port elizabeth
# Processing Record 1 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bengkulu
# Processing Record 1 of Set 1 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=quatre cocos
# Processing Record 1 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=faanui
# Processing Record 1 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yellowknife
# Processing Record 1 of Set 1 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hobyo
# Processing Record 1 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=avarua
# Processing Record 1 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yulara
# Processing Record 1 of Set 1 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=atasu
# Processing Record 1 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=albany
# Processing Record 1 of Set 1 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bandarbeyla
# Processing Record 1 of Set 1 | carlagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=carlagan
# Processing Record 1 of Set 1 | dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=dandong
# Processing Record 1 of Set 1 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vardo
# Processing Record 1 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=butaritari
# Processing Record 1 of Set 1 | kukshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kukshi
# Processing Record 1 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tiksi
# Processing Record 1 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=norman wells
# Processing Record 1 of Set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sitka
# Processing Record 1 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bluff
# Processing Record 1 of Set 1 | niksic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=niksic
# Processing Record 1 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bambous virieux
# Processing Record 1 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nikolskoye
# Processing Record 1 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kapaa
# Processing Record 1 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vaini
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ushuaia
# Processing Record 1 of Set 1 | corinto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=corinto
# Processing Record 1 of Set 1 | varazdin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=varazdin
# Processing Record 1 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=arraial do cabo
# Processing Record 1 of Set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vila velha
# Processing Record 1 of Set 1 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=camacha
# Processing Record 1 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=busselton
# Processing Record 1 of Set 1 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kalmunai
# Processing Record 1 of Set 1 | sucre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sucre
# Processing Record 1 of Set 1 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bubaque
# Processing Record 1 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chuy
# Processing Record 1 of Set 1 | paka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=paka
# Processing Record 0 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chokurdakh
# Processing Record 1 of Set 1 | rokytne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rokytne
# Processing Record 1 of Set 1 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sur
# Processing Record 1 of Set 1 | enniskerry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=enniskerry
# Processing Record 1 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kodiak
# Processing Record 1 of Set 1 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=caravelas
# Processing Record 1 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rikitea
# Processing Record 1 of Set 1 | forbes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=forbes
# Processing Record 1 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ponta do sol
# Processing Record 1 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tuktoyaktuk
# Processing Record 1 of Set 1 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=meulaboh
# Processing Record 1 of Set 1 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=saleaula
# City not found. Skipping...
# Processing Record 1 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=saldanha
# Processing Record 1 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=dikson
# Processing Record 1 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pangnirtung
# Processing Record 1 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cabo san lucas
# Processing Record 1 of Set 1 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=usinsk
# Processing Record 1 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kruisfontein
# Processing Record 1 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nanortalik
# Processing Record 1 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cidreira
# Processing Record 1 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=torbay
# Processing Record 1 of Set 1 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kulhudhuffushi
# Processing Record 1 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=atuona
# Processing Record 1 of Set 1 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=alyangula
# Processing Record 1 of Set 1 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mount gambier
# Processing Record 1 of Set 1 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=maragogi
# Processing Record 1 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mar del plata
# Processing Record 1 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vila franca do campo
# Processing Record 1 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=constitucion
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hobart
# Processing Record 1 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=punta arenas
# Processing Record 1 of Set 1 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=goderich
# Processing Record 1 of Set 1 | pestravka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pestravka
# Processing Record 1 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=barrow
# Processing Record 1 of Set 1 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port blair
# Processing Record 1 of Set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sao filipe
# Processing Record 1 of Set 1 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=marcona
# City not found. Skipping...
# Processing Record 1 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=klaksvik
# Processing Record 1 of Set 1 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yarada
# Processing Record 1 of Set 1 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mnogovershinnyy
# Processing Record 1 of Set 1 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mahibadhoo
# Processing Record 1 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=qaanaaq
# Processing Record 1 of Set 1 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=akyab
# Processing Record 1 of Set 1 | salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=salamiyah
# Processing Record 1 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pevek
# Processing Record 1 of Set 1 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tual
# Processing Record 1 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=leningradskiy
# Processing Record 1 of Set 1 | abnub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=abnub
# Processing Record 1 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=saskylakh
# Processing Record 0 of Set 1 | beya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=beya
# Processing Record 1 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port alfred
# Processing Record 1 of Set 1 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=huilong
# Processing Record 1 of Set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=aklavik
# Processing Record 1 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hilo
# Processing Record 1 of Set 1 | kaman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kaman
# Processing Record 1 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=amderma
# City not found. Skipping...
# Processing Record 1 of Set 1 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kidal
# Processing Record 1 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pisco
# Processing Record 1 of Set 1 | derbent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=derbent
# Processing Record 1 of Set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=coquimbo
# Processing Record 1 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=carnarvon
# Processing Record 1 of Set 1 | panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=panguna
# Processing Record 1 of Set 1 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=along
# Processing Record 1 of Set 1 | tianpeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tianpeng
# Processing Record 1 of Set 1 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=roma
# Processing Record 1 of Set 1 | kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kamenka
# Processing Record 1 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ilulissat
# Processing Record 1 of Set 1 | magadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=magadan
# Processing Record 1 of Set 1 | rena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rena
# Processing Record 1 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tasiilaq
# Processing Record 1 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bredasdorp
# Processing Record 1 of Set 1 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yerbogachen
# Processing Record 1 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hithadhoo
# Processing Record 1 of Set 1 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ponta delgada
# Processing Record 1 of Set 1 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=noumea
# Processing Record 1 of Set 1 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 1 | olovyannaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=olovyannaya
# Processing Record 1 of Set 1 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bundaberg
# Processing Record 1 of Set 1 | garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=garowe
# Processing Record 1 of Set 1 | baker city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=baker city
# Processing Record 1 of Set 1 | marv dasht
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=marv dasht
# City not found. Skipping...
# Processing Record 1 of Set 1 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=akdepe
# Processing Record 1 of Set 1 | porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=porbandar
# Processing Record 1 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tuatapere
# Processing Record 1 of Set 1 | jizan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=jizan
# Processing Record 1 of Set 1 | show low
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=show low
# Processing Record 1 of Set 1 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 1 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 1 | deer lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=deer lake
# Processing Record 1 of Set 1 | san felipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=san felipe
# Processing Record 1 of Set 1 | koulikoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=koulikoro
# Processing Record 1 of Set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=luderitz
# Processing Record 1 of Set 1 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hovd
# Processing Record 1 of Set 1 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=praia da vitoria
# Processing Record 1 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 1 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=gat
# Processing Record 1 of Set 1 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=taksimo
# Processing Record 1 of Set 1 | mergui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mergui
# City not found. Skipping...
# Processing Record 1 of Set 1 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kiama
# Processing Record 0 of Set 1 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mayo
# Processing Record 1 of Set 1 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=paamiut
# Processing Record 1 of Set 1 | hede
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hede
# Processing Record 1 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=severo-kurilsk
# Processing Record 1 of Set 1 | lillooet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lillooet
# Processing Record 1 of Set 1 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=awjilah
# Processing Record 1 of Set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lorengau
# Processing Record 1 of Set 1 | eenhana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=eenhana
# Processing Record 1 of Set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 1 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=abu kamal
# Processing Record 1 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ribeira grande
# Processing Record 1 of Set 1 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=zhigansk
# Processing Record 1 of Set 1 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port-gentil
# Processing Record 1 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=east london
# Processing Record 1 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hermanus
# Processing Record 1 of Set 1 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=jalu
# Processing Record 1 of Set 1 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=grindavik
# Processing Record 1 of Set 1 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=beyneu
# Processing Record 1 of Set 1 | bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bairiki
# Processing Record 1 of Set 1 | vrchlabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vrchlabi
# Processing Record 1 of Set 1 | pitanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pitanga
# Processing Record 1 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kaitangata
# Processing Record 1 of Set 1 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nuuk
# Processing Record 1 of Set 1 | diebougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=diebougou
# Processing Record 1 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lagoa
# Processing Record 1 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=esperance
# Processing Record 1 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=new norfolk
# Processing Record 1 of Set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=namatanai
# Processing Record 1 of Set 1 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=fort nelson
# Processing Record 1 of Set 1 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=portland
# Processing Record 1 of Set 1 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=batagay-alyta
# Processing Record 1 of Set 1 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=acajutla
# Processing Record 1 of Set 1 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lolua
# City not found. Skipping...
# Processing Record 1 of Set 1 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tautira
# Processing Record 1 of Set 1 | challapata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=challapata
# Processing Record 1 of Set 1 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=san patricio
# Processing Record 1 of Set 1 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nalut
# Processing Record 1 of Set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nome
# Processing Record 1 of Set 1 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=margate
# Processing Record 1 of Set 1 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kawalu
# Processing Record 1 of Set 1 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=srednekolymsk
# Processing Record 1 of Set 1 | owando
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=owando
# Processing Record 1 of Set 1 | andevoranto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 1 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=los llanos de aridane
# Processing Record 1 of Set 1 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=miri
# Processing Record 1 of Set 1 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=olafsvik
# Processing Record 1 of Set 1 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nouadhibou
# Processing Record 1 of Set 1 | sri aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sri aman
# Processing Record 1 of Set 1 | manavgat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=manavgat
# Processing Record 1 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=provideniya
# Processing Record 0 of Set 1 | liwale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=liwale
# Processing Record 1 of Set 1 | katha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=katha
# City not found. Skipping...
# Processing Record 1 of Set 1 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pangody
# Processing Record 1 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cherskiy
# Processing Record 1 of Set 1 | ust-ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ust-ishim
# Processing Record 1 of Set 1 | rancho palos verdes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rancho palos verdes
# Processing Record 1 of Set 1 | pietarsaari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pietarsaari
# Processing Record 1 of Set 1 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vao
# Processing Record 1 of Set 1 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=riohacha
# Processing Record 1 of Set 1 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bull savanna
# Processing Record 1 of Set 1 | tyup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tyup
# Processing Record 1 of Set 1 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=urumqi
# City not found. Skipping...
# Processing Record 1 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=georgetown
# Processing Record 1 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 1 | campo maior
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=campo maior
# Processing Record 1 of Set 1 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=san jose
# Processing Record 1 of Set 1 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=okha
# Processing Record 1 of Set 1 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=toliary
# City not found. Skipping...
# Processing Record 1 of Set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cockburn town
# Processing Record 1 of Set 1 | kisiwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kisiwani
# Processing Record 1 of Set 1 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=jumla
# Processing Record 1 of Set 1 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=grand gaube
# Processing Record 1 of Set 1 | labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=labutta
# City not found. Skipping...
# Processing Record 1 of Set 1 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=antalaha
# Processing Record 1 of Set 1 | paracuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=paracuru
# Processing Record 1 of Set 1 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rocha
# Processing Record 1 of Set 1 | nueva concepcion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nueva concepcion
# Processing Record 1 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kavieng
# Processing Record 1 of Set 1 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=krasnoselkup
# Processing Record 1 of Set 1 | zomin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=zomin
# Processing Record 1 of Set 1 | moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=moree
# Processing Record 1 of Set 1 | kashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kashi
# Processing Record 1 of Set 1 | yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yining
# Processing Record 1 of Set 1 | noshiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=noshiro
# Processing Record 1 of Set 1 | oriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=oriximina
# Processing Record 1 of Set 1 | miraflores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=miraflores
# Processing Record 1 of Set 1 | sayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sayan
# Processing Record 1 of Set 1 | creston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=creston
# Processing Record 1 of Set 1 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bargal
# City not found. Skipping...
# Processing Record 1 of Set 1 | piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=piacabucu
# Processing Record 1 of Set 1 | prado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=prado
# Processing Record 1 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=upernavik
# Processing Record 1 of Set 1 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=charters towers
# Processing Record 1 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mahebourg
# Processing Record 1 of Set 1 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=brae
# Processing Record 1 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=saint-philippe
# Processing Record 1 of Set 1 | dedza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=dedza
# Processing Record 1 of Set 1 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sibu
# Processing Record 1 of Set 1 | sooke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sooke
# Processing Record 1 of Set 1 | chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chikoy
# City not found. Skipping...
# Processing Record 0 of Set 1 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tarko-sale
# Processing Record 1 of Set 1 | wexford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=wexford
# Processing Record 1 of Set 1 | raymondville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=raymondville
# Processing Record 1 of Set 1 | ekibastuz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ekibastuz
# Processing Record 1 of Set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port hardy
# Processing Record 1 of Set 1 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=umm kaddadah
# Processing Record 1 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hamilton
# Processing Record 1 of Set 1 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bontang
# Processing Record 1 of Set 1 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cairns
# Processing Record 1 of Set 1 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=egvekinot
# Processing Record 1 of Set 1 | peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=peleduy
# Processing Record 1 of Set 1 | sidney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sidney
# Processing Record 1 of Set 1 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=waipawa
# Processing Record 1 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=narsaq
# Processing Record 1 of Set 1 | tubruq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tubruq
# City not found. Skipping...
# Processing Record 1 of Set 1 | siparia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=siparia
# Processing Record 1 of Set 1 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=talnakh
# Processing Record 1 of Set 1 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=coahuayana
# Processing Record 1 of Set 1 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hervey bay
# Processing Record 1 of Set 1 | kadoshkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kadoshkino
# Processing Record 1 of Set 1 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=mackay
# Processing Record 1 of Set 1 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=acapulco
# Processing Record 1 of Set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=fairbanks
# Processing Record 1 of Set 1 | tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tagusao
# Processing Record 1 of Set 1 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=conceicao do araguaia
# Processing Record 1 of Set 1 | creel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=creel
# Processing Record 1 of Set 1 | sheridan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sheridan
# Processing Record 1 of Set 1 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chagda
# City not found. Skipping...
# Processing Record 1 of Set 1 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ostrovnoy
# Processing Record 1 of Set 1 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 1 | nuevitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nuevitas
# Processing Record 1 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=saint george
# Processing Record 1 of Set 1 | san julian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=san julian
# Processing Record 1 of Set 1 | chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chifeng
# Processing Record 1 of Set 1 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=arlit
# Processing Record 1 of Set 1 | galesong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=galesong
# Processing Record 1 of Set 1 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=burnie
# Processing Record 1 of Set 1 | kardailovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kardailovo
# Processing Record 1 of Set 1 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=adrar
# Processing Record 1 of Set 1 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=beloha
# Processing Record 1 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kahului
# Processing Record 1 of Set 1 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=khonuu
# City not found. Skipping...
# Processing Record 1 of Set 1 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cabedelo
# Processing Record 1 of Set 1 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 1 | koson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=koson
# Processing Record 1 of Set 1 | senneterre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=senneterre
# Processing Record 1 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 1 | contramaestre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=contramaestre
# Processing Record 1 of Set 1 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=boca do acre
# Processing Record 0 of Set 1 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ambon
# Processing Record 1 of Set 1 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sola
# Processing Record 1 of Set 1 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=aripuana
# Processing Record 1 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=salalah
# Processing Record 1 of Set 1 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=airai
# Processing Record 1 of Set 1 | plainview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=plainview
# Processing Record 1 of Set 1 | middelburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=middelburg
# Processing Record 1 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=khatanga
# Processing Record 1 of Set 1 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=haines junction
# ...
# Processing Record 1 of Set 1 | koungou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=koungou
# Processing Record 1 of Set 1 | banfora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=banfora
# Processing Record 1 of Set 1 | sapouy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sapouy
# Processing Record 1 of Set 1 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lasa
# Processing Record 1 of Set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lavrentiya
# Processing Record 1 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=souillac
# Processing Record 1 of Set 1 | una
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=una
# Processing Record 1 of Set 1 | maniwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=maniwaki
# Processing Record 1 of Set 1 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=la ronge
# Processing Record 1 of Set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 1 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pringsewu
# Processing Record 1 of Set 1 | lucapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lucapa
# Processing Record 1 of Set 1 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bilibino
# Processing Record 1 of Set 1 | stromness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=stromness
# Processing Record 1 of Set 1 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=solnechnyy
# Processing Record 1 of Set 1 | snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=snezhnogorsk
# Processing Record 1 of Set 1 | cabadiangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cabadiangan
# Processing Record 1 of Set 1 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sakaiminato
# Processing Record 1 of Set 1 | danjiangkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=danjiangkou
# Processing Record 1 of Set 1 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port augusta
# Processing Record 1 of Set 1 | obihiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=obihiro
# Processing Record 1 of Set 1 | nanchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nanchang
# Processing Record 1 of Set 1 | laramie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=laramie
# Processing Record 1 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ahipara
# Processing Record 1 of Set 1 | muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=muli
# Processing Record 1 of Set 1 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=eureka
# Processing Record 1 of Set 1 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chapais
# Processing Record 1 of Set 1 | burgersdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=burgersdorp
# Processing Record 0 of Set 1 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ketchikan
# Processing Record 1 of Set 1 | pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pandan
# Processing Record 1 of Set 1 | ramanuj ganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ramanuj ganj
# Processing Record 1 of Set 1 | deshnok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=deshnok
# Processing Record 1 of Set 1 | lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lamar
# Processing Record 1 of Set 1 | sigli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sigli
# Processing Record 1 of Set 1 | envira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=envira
# Processing Record 1 of Set 1 | bembereke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bembereke
# Processing Record 1 of Set 1 | yokadouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yokadouma
# Processing Record 1 of Set 1 | yetholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yetholm
# City not found. Skipping...
# Processing Record 1 of Set 1 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kemijarvi
# Processing Record 1 of Set 1 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=okhotsk
# Processing Record 1 of Set 1 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=takoradi
# Processing Record 1 of Set 1 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bac lieu
# Processing Record 1 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=lompoc
# Processing Record 1 of Set 1 | onguday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=onguday
# Processing Record 1 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hasaki
# Processing Record 1 of Set 1 | marondera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=marondera
# Processing Record 1 of Set 1 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hualmay
# Processing Record 1 of Set 1 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=guerrero negro
# Processing Record 1 of Set 1 | bacuit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bacuit
# City not found. Skipping...
# Processing Record 1 of Set 1 | porto velho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=porto velho
# Processing Record 1 of Set 1 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=asau
# Processing Record 1 of Set 1 | cua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cua
# Processing Record 1 of Set 1 | tombouctou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tombouctou
# Processing Record 1 of Set 1 | bindura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bindura
# Processing Record 1 of Set 1 | tolaga bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tolaga bay
# Processing Record 1 of Set 1 | nacogdoches
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=nacogdoches
# Processing Record 1 of Set 1 | fowa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=fowa
# Processing Record 1 of Set 1 | arona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=arona
# Processing Record 1 of Set 1 | barybino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=barybino
# Processing Record 1 of Set 1 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=halalo
# City not found. Skipping...
# Processing Record 1 of Set 1 | ivdel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ivdel
# Processing Record 1 of Set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=palmer
# Processing Record 1 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=touros
# Processing Record 1 of Set 1 | novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=novobirilyussy
# Processing Record 1 of Set 1 | alamogordo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=alamogordo
# Processing Record 1 of Set 1 | rong kwang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=rong kwang
# Processing Record 1 of Set 1 | union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=union
# Processing Record 1 of Set 1 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=matay
# Processing Record 1 of Set 1 | dalnerechensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=dalnerechensk
# Processing Record 1 of Set 1 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=cayenne
# Processing Record 1 of Set 1 | sattahip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=sattahip
# Processing Record 1 of Set 1 | tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tigil
# Processing Record 1 of Set 1 | emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=emba
# Processing Record 1 of Set 1 | moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=moindou
# Processing Record 1 of Set 1 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=preobrazheniye
# Processing Record 1 of Set 1 | coari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=coari
# Processing Record 1 of Set 1 | bom jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=bom jesus
# Processing Record 1 of Set 1 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hit
# Processing Record 0 of Set 1 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ancud
# Processing Record 1 of Set 1 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=port macquarie
# Processing Record 1 of Set 1 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=meyungs
# City not found. Skipping...
# Processing Record 1 of Set 1 | roncesvalles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=roncesvalles
# Processing Record 1 of Set 1 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=tiarei
# Processing Record 1 of Set 1 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=labuhan
# Processing Record 1 of Set 1 | khorixas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=khorixas
# Processing Record 1 of Set 1 | ken caryl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=ken caryl
# Processing Record 1 of Set 1 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=faya
# Processing Record 1 of Set 1 | palizada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=palizada
# Processing Record 1 of Set 1 | pachino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pachino
# Processing Record 1 of Set 1 | kifri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kifri
# Processing Record 1 of Set 1 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=gamba
# Processing Record 1 of Set 1 | chambery
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chambery
# Processing Record 1 of Set 1 | porto santo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=porto santo
# Processing Record 1 of Set 1 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=chicama
# Processing Record 1 of Set 1 | virginia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=virginia
# Processing Record 1 of Set 1 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kieta
# Processing Record 1 of Set 1 | pauini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=pauini
# Processing Record 1 of Set 1 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=kisangani
# Processing Record 1 of Set 1 | florida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=florida
# Processing Record 1 of Set 1 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=hofn
# Processing Record 1 of Set 1 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=the valley
# Processing Record 1 of Set 1 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=miyako
# Processing Record 1 of Set 1 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=yenagoa
# Processing Record 1 of Set 1 | imeni babushkina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe00099152b89472cf7eb43b988deacf&q=imeni babushkina
# -------------------------------------
# Data Retrieval Complete
# -------------------------------------

# %%
#print (city_weather)
city_data_df = pd.DataFrame(city_data)
#city_data_pd.head()

# %%
# Convert the cities weather data into a Pandas DataFrame
#city_data_df = # YOUR CODE HERE

lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]



# Show Record Count
city_data_df.count()
# Out:
# City          529
# Lat           529
# Lng           529
# Max Temp      529
# Humidity      529
# Cloudiness    529
# Wind Speed    529
# Country       529
# Date          529
# dtype: int64

# %%
# Display sample data
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            mataura -46.1927  168.8643     63.48        35          62
# 1            batagay  67.6333  134.6333    -42.39        94          92
# 2  dabrowa tarnowska  50.1746   20.9863     24.44        87          81
# 3          cape town -33.9258   18.4232     70.92        75           0
# 4          jamestown  42.0970  -79.2353     47.01        89         100
#
#    Wind Speed Country        Date
# 0        5.79      NZ  1675999121
# 1        0.98      RU  1675999121
# 2        6.11      PL  1675999121
# 3       10.00      ZA  1675999122
# 4       13.80      US  1675999122

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  mataura -46.1927  168.8643     63.48        35          62
# 1                  batagay  67.6333  134.6333    -42.39        94          92
# 2        dabrowa tarnowska  50.1746   20.9863     24.44        87          81
# 3                cape town -33.9258   18.4232     70.92        75           0
# 4                jamestown  42.0970  -79.2353     47.01        89         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.79      NZ  1675999121
# 1              0.98      RU  1675999121
# 2              6.11      PL  1675999121
# 3             10.00      ZA  1675999122
# 4             13.80      US  1675999122

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.scatter(lats, max_temps, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title(f"City Latitude v Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid(True)

plt.savefig("output_data/Fig1.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.scatter(lats, humidity, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title(f"City Latitude v Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
plt.scatter(lats, cloudiness, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("output_data/Fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

plt.scatter(lats, wind_speed, edgecolor="black", linewidth=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("output_data/Fig4.png")
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) > 0, :]
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) < 0, :]

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                  batagay  67.6333  134.6333    -42.39        94          92
# 2        dabrowa tarnowska  50.1746   20.9863     24.44        87          81
# 4                jamestown  42.0970  -79.2353     47.01        89         100
# 5                   eregli  37.5133   34.0467     15.67        84          66
# 6                 agropoli  40.3469   14.9966     39.15        78         100
#
#          Wind Speed Country        Date
# City_ID
# 1              0.98      RU  1675999121
# 2              6.11      PL  1675999121
# 4             13.80      US  1675999122
# 5              2.86      TR  1675999123
# 6              8.79      IT  1675999123

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               mataura -46.1927  168.8643     63.48        35          62
# 3             cape town -33.9258   18.4232     70.92        75           0
# 7                castro -24.7911  -50.0119     66.15        80          93
# 9          puerto ayora  -0.7393  -90.3518     78.55        91          82
# 11       port elizabeth -33.9180   25.5701     63.10        94           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.79      NZ  1675999121
# 3             10.00      ZA  1675999122
# 7              3.04      BR  1675999123
# 9              5.91      EC  1675999124
# 11             3.44      ZA  1675999125

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
#plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression displays a negative correlation.")
#print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# The r-squared is: -0.8722936377059998

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
#plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression displays a positive correlation.")
#print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# The r-squared is: 0.35493303770358164

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
#plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# The r-squared is: 0.4156935299520258

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
#plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# The r-squared is: 0.32092609605598127

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
#plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# The r-squared is: 0.3740512001870493

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
#plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# The r-squared is: 0.33311293456112806

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
#plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# The r-squared is: 0.1344292279129406

# %%
# Southern Hemisphere
# YOUR CODE HERE

x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
#plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
#print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# The r-squared is: -0.21700881919786166

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
